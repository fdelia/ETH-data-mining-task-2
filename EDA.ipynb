# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.loadtxt('data/handout_train.txt')
#Y = X[:, :1]
#X = X[:, 1:]

# %%
plt.figure(figsize=(20,10))
plt.hist(np.mean(X[X[:, 1]>0][:, 1:], axis=0), 200, normed=1, facecolor='green', alpha=0.75, label='class 1')
plt.hist(np.mean(X[X[:, 1]<0][:, 1:], axis=0), 200, normed=1, facecolor='red', alpha=0.75, label='class -1')
plt.xlim([-0.0015, 0.0018])
plt.legend()
plt.show()

# %%
X[X[:, 1]>0][:, 1:]
# Out:
# array([[ 0.00965844, -0.00496035,  0.01082632, ..., -0.02232313,
#         -0.01465736, -0.01119307],
#        [ 0.0008721 ,  0.00838457,  0.01351237, ..., -0.0046109 ,
#         -0.00789353, -0.01508342],
#        [ 0.01043964,  0.00376671,  0.0097485 , ..., -0.01792164,
#          0.00620539, -0.02043598],
#        ...,
#        [ 0.02106533, -0.01502542,  0.02096058, ..., -0.01502496,
#          0.00104391,  0.01382377],
#        [ 0.01018744, -0.00149794, -0.00401092, ...,  0.02203963,
#         -0.01218405,  0.00704509],
#        [ 0.00036208, -0.00695101, -0.01855274, ...,  0.0017109 ,
#          0.01368193,  0.00596735]])
